# %% [markdown]
# ### 📜 AI의 여정: 겨울을 지나 맞이한 새로운 부흥
#
# 우리가 지금 사용하는 Gemini와 같은 인공지능은 어느 날 갑자기 나타난 것이 아닙니다. 아래 그래프는 1956년 AI가 탄생한 이래, 수많은 기대와 실망, 그리고 부흥을 거쳐온 파란만장한 역사를 보여줍니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | 시기 (Period) | 상태 (Era Name) | 주요 사건 및 원인 |
# | :--- | :--- | :--- |
# | **1956년 ~ 1974년** | **1차 황금기 (The First Golden Age)** | • "AI의 탄생": 컴퓨터가 인간처럼 생각할 수 있다는 기대감 폭발<br>• 그러나, 기술적 한계와 비현실적인 목표로 인해 점차 연구 방향 상실 |
# | **1974년 ~ 1980년** | **1차 암흑기 (The First Winter)** | • 초기의 약속을 지키지 못하자 연구 자금이 끊기고 대중의 관심이 식음<br>• AI 기술에 대한 깊은 회의감이 팽배했던 시기 |
# | **1980년 ~ 1987년** | **2차 부흥기 (The Second Surge)** | • **'전문가 시스템(Expert Systems)'**의 성공: 특정 분야의 전문가 지식을 담아 문제를 해결하는 AI가 상업적 가능성을 보임 |
# | **1987년 ~ 1993년** | **2차 암흑기 (The Second Decline)** | • 전문가 시스템의 한계 봉착: 유지보수가 어렵고, 새로운 지식을 학습하기 어려워 다시 침체기를 맞이함 |
# | **1993년 ~ 현재** | **새로운 부흥 (The New Upsurge)** | • **새로운 IT 기술(인터넷, 컴퓨팅 파워)의 발전**이 토대를 마련<br>• **'딥러닝(Deep Learning)'과 '빅데이터(Big Data)'의 폭발**적인 결합으로 AI 기술이 비약적으로 발전하며 현재의 AI 혁명을 이끎 |

# %% [markdown]
# #### **그래서 지금 우리는 어디에 있을까요?**
#
# 바로 이 그래프의 가장 오른쪽, **'새로운 부흥(The New Upsurge)'** 시대를 살고 있습니다. 특히 2010년 이후 시작된 **딥러닝과 빅데이터의 혁명**은 과거의 AI 겨울과는 비교할 수 없는 엄청난 성장을 이끌어냈습니다.
#
# 우리가 지금부터 다룰 **Gemini**와 같은 거대 언어 모델(LLM)은 바로 이 새로운 부흥기의 가장 빛나는 결과물 중 하나입니다. 수십 년간 쌓아온 연구와 기술 발전의 정점에 서 있는 것이죠.
#
# 이 역사적인 맥락을 이해하면, 우리가 단지 신기한 기술을 체험하는 것을 넘어, 인류 지성사의 중요한 변곡점에 함께하고 있다는 사실을 깨닫게 될 것입니다.

# %% [markdown]
# ### 📊 객관적인 데이터로 보는 Gemini의 위상
#
# 우리가 왜 Gemini를 선택했는지에 대한 또 다른 강력한 근거는 객관적인 성능 평가 지표에 있습니다. 아래 차트는 다양한 최신 AI 모델들을 서로 비교하여 '평균 승률(Average Win Rate)'을 측정한 결과를 보여줍니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이 차트는 특정 질문(프롬프트)에 대해 어떤 모델의 답변이 더 우수한지를 평가하는 블라인드 테스트 기반의 벤치마크 결과로, 현재 AI 기술의 경쟁 구도를 한눈에 파악할 수 있는 중요한 자료입니다.
#
# #### **차트에서 알 수 있는 핵심 정보 (Key Insights)**
#
# *   🥇 **압도적인 1위, `gemini-2.5-pro`**: 우리가 실습에서 사용하고 있는 **`gemini-2.5-pro` 모델이 66%라는 가장 높은 평균 승률**로 1위를 차지하고 있습니다. 이는 다른 모든 경쟁 모델들과의 비교 평가에서 가장 꾸준하고 뛰어난 성능을 보였다는 것을 의미합니다.
#
# *   🥈 **치열한 상위권 경쟁**: 그 뒤를 `gpt-4.5-high` (61%), `gpt-4.5-preview` (56%), `chatgpt-4o` (54%) 등의 모델들이 바짝 쫓으며, AI 기술이 얼마나 빠르게 발전하고 경쟁이 치열한지 보여줍니다.
#
# *   📈 **'평균 승률'의 의미**: 차트 제목의 'Average Win Rate Against All Other Models'는 특정 모델이 다른 모든 모델과 1:1로 경쟁했을 때, 그 답변이 더 우수하다고 평가받은 비율의 평균입니다. 즉, 이 점수가 높을수록 **전반적으로 더 똑똑하고 유능한 모델**이라고 해석할 수 있습니다.
#
# #### **결론: 최고의 도구로 최상의 경험을**
#
# 이러한 객관적인 성능 지표는 우리가 이번 실습의 파트너로 **Gemini를 선택한 것이 탁월한 결정**이었음을 명확하게 보여줍니다. 우리는 현재 공개된 모델 중 가장 뛰어난 성능을 보이는 도구를 사용하여, AI 기술의 최전선을 직접 경험하고 있는 것입니다.

# %% [markdown]
# # 🤔 왜 많고 많은 AI 중에 **Gemini**를 사용할까요?
#
# 세상에는 정말 다양한 AI 모델이 있습니다. 그런데 왜 우리는 이 실습에서 **Google의 Gemini**를 선택했을까요? 단순히 '최신'이기 때문만은 아닙니다. 우리의 **실습 목표와 환경에 가장 완벽하게 부합**하기 때문입니다.
#
# 간단히 말해, Gemini는 **'진정한 멀티모달'을 경험**하고, **'Google Colab' 환경에서 가장 쉽게 사용**할 수 있는 최적의 선택입니다.
#
#
# ### **1. '진정한 멀티모달'을 위한 최고의 도구**
#
# *   **따로따로 vs. 한 번에:** 기존 모델들은 이미지, 음성, 텍스트를 각각 별개의 모델(전문가)이 처리한 뒤 결과를 합치는 방식에 가까웠습니다. 마치 시각 전문가, 청각 전문가, 언어 전문가가 회의를 하는 것과 같죠.
# *   **Gemini의 방식:** 반면, Gemini는 설계부터 이미지, 오디오, 텍스트 등 다양한 종류의 데이터를 **하나의 모델이 처음부터 함께** 받아들여 통합적으로 이해합니다. 이는 마치 우리가 눈으로 보고, 귀로 들으며 **동시에 상황을 인지**하는 방식과 매우 유사합니다.
#
# > 이번 실습의 목표인 '이미지와 음성을 동시에 입력받아 상황을 이해하는 챗봇'을 만드는 데 있어, 이러한 **'네이티브 멀티모달'** 아키텍처를 가진 Gemini는 가장 이상적인 도구입니다.
#
# ### **2. Google Colab 환경과의 완벽한 시너지**
#
# 우리는 지금 **Google Colab**이라는 구글의 개발 환경을 사용하고 있습니다. 당연히 구글이 만든 Gemini 모델과 가장 잘 맞습니다.
#
# *   **간편한 설정:** `!pip install google-generativeai` 명령어 하나로 라이브러리를 설치하고, Colab의 '보안 비밀' 기능으로 API 키를 안전하고 쉽게 연동할 수 있습니다. 복잡한 인증 절차나 환경 설정이 필요 없습니다.
# *   **안정적인 연동:** 같은 구글 생태계 안에서 작동하므로, 모델을 호출하고 데이터를 주고받는 과정이 매우 안정적이고 빠릅니다.
#
# ### **3. 세계 최고 수준의 성능과 최신 기술**
#
# 우리는 이 실습을 통해 단순히 AI를 '사용'하는 것을 넘어, **현재 가장 발전된 기술**이 어디까지 왔는지 직접 체험하고자 합니다.
#
# *   **Gemini 2.5 Pro:** 우리가 사용하는 `gemini-2.5-pro` 모델은 방대한 양의 정보를 한 번에 처리하고, 복잡한 지시사항을 이해하며, 고도의 추론 능력을 보여주는 현존하는 가장 강력한 모델 중 하나입니다.
# *   **미래 기술 경험:** Gemini를 사용함으로써 우리는 AI 기술의 최전선을 직접 경험하고, 앞으로 AI가 어떻게 발전해 나갈지 엿볼 수 있습니다.
#
# ### **4. 편리한 접근성과 개발자 친화적 생태계**
#
# 아무리 좋은 기술이라도 사용하기 어렵거나 비싸면 그림의 떡입니다.
#
# *   **무료 API 키:** [Google AI Studio](https://aistudio.google.com/)를 통해 누구나 쉽게 무료로 API 키를 발급받아 Gemini의 강력한 기능을 테스트해 볼 수 있습니다. 이는 학습자에게 매우 큰 장점입니다.
# *   **지속적인 발전:** Gemini는 계속해서 새로운 기능(실시간 스트리밍, 함수 호출 등)이 추가되고 있으며, 개발자들이 이를 쉽게 활용할 수 있도록 풍부한 문서와 예제를 제공합니다.
#
# ---
#
# ### **결론: 우리 실습을 위한 최고의 파트너**
#
# | 핵심 특징 (Key Feature) | 왜 우리 실습에 중요한가요? |
# | :--- | :--- |
# | **네이티브 멀티모달** | 이미지와 오디오를 '동시에' 이해하는 실습 목표에 완벽 부합합니다. |
# | **Colab 환경 통합** | 복잡한 설정 없이 코드 몇 줄만으로 쉽고 빠르게 AI를 연동할 수 있습니다. |
# | **최고 수준 성능** | AI 기술의 최전선을 직접 맛보고, 강력한 결과물을 얻을 수 있습니다. |
# | **뛰어난 접근성** | 누구나 무료로 시작할 수 있어 학습 장벽이 매우 낮습니다. |
#
# 이러한 이유들로 우리는 이번 실습의 파트셔로 **Gemini**를 선택했습니다. 이제 이 강력한 도구를 직접 다뤄보며 AI의 놀라운 가능성을 함께 탐험해 봅시다

# %% [markdown]
# ### **1. Gemini 2.5 Pro: 네이티브 오디오 + 이미지 멀티모달 체험**
#
# **활동 목표:** 이미지와 음성을 **동시에** 입력받아 상황을 이해하고 답변하는 음성 인식 챗봇을 만듭니다. 이를 통해 Gemini가 단순히 텍스트를 넘어 시청각 정보를 함께 처리하는 '네이티브 멀티모달'을 직접 경험합니다.
#
# **기존 멀티 모달과 네이티브 멀티 모달의 차이**
#
# * 기존 멀티모달: 이미지 인식 모델, 음성 인식 모델, 언어 모델이 각각의 결과를 합치는 방식.
#
# * **네이티브 멀티모달 (Gemini 2.5 Pro):** 하나의 모델이 처음부터 이미지와 오디오 스트림을 함께 받아들여 통합적으로 이해. 마치 우리가 눈으로 보고 귀로 들으며 상황을 파악하는 것과 유사합니다.

# %% [markdown]
# ### **1. AI를 위한 도구 상자, 라이브러리 설치하기**
#
# AI와 대화하고, 이미지를 보여주려면 몇 가지 특별한 '연장'이 필요합니다. 파이썬에서는 이런 연장들을 **라이브러리(Library)**라고 부릅니다. 다행히 우리는 이 연장들을 직접 만들 필요 없이, 이미 잘 만들어진 **'도구 상자'**를 가져와 쓰기만 하면 됩니다.
#
# #### **이번 실습에 필요한 도구들**
#
# 우리는 딱 2개의 도구 상자만 설치하면 됩니다.
#
# | 라이브러리 (도구 상자) | 역할 (하는 일) |
# | :--- | :--- |
# | `google-generativeai` | Gemini AI와 소통하는 **메인 통신선**. 이 실습의 심장과도 같습니다. |
# | `Pillow` | 이미지를 다루는 **디지털 사진사**. 웹캠 사진을 AI가 이해하도록 돕습니다. |

# %%
# 먼저 pip부터 업그레이드해주는 것이 좋습니다.
# !pip install --upgrade pip

# 이제 우리가 필요한 라이브러리를 설치합니다.
# 붉은색 경고 메시지가 나타나도 괜찮습니다!
# !pip install -q -U google-generativeai pillow

# %% [markdown]
# ### **2. API 키 인증하기**
#
# API 키 인증은 [**사전 준비사항에서 다루었습니다.**](./PREPARE.md) 혹시 그 단계를 놓쳤거나 확인하고 싶으시다면 아래 가이드를 따라 진행해주세요. API 키는 우리가 Gemini AI를 사용할 자격이 있다는 것을 증명하는 '비밀 열쇠'입니다. 이 열쇠는 다른 사람에게 절대 노출되면 안 됩니다.
#
# Google Colab에는 이런 비밀 키를 안전하게 보관하는 **'보안 비밀(Secrets)'** 기능이 있습니다.
#
#   * **[등록 방법](./PREPARE.md) (사전 준비사항에서 API키를 가져왔다면, 코드에서 키 불러오기 파트를 진행해주세요)**
#
#     1.  Colab 화면 왼쪽 사이드바에서 **열쇠 모양(🔑) 아이콘**을 클릭하세요. '보안 비밀' 탭이 열립니다.
#
#     2.  **`+ 새 보안 비밀 추가`** 버튼을 클릭하세요.
#
#     3.  두 개의 입력 칸이 나타납니다.
#
#           * **이름(Name):** `GOOGLE_API_KEY` 라고 **똑같이** 입력하세요. (대소문자 구분)
#           * **값(Value):** 사전 준비 단계에서 Google AI Studio를 통해 발급받아 메모장에 복사해 둔 `AIzaSy...`로 시작하는 긴 문자열을 **붙여넣기** 하세요.
#
#     4.  입력이 끝났으면 오른쪽에 있는 **토글 버튼을 켜서** 이 노트북에서 키를 사용할 수 있도록 활성화해주세요. (버튼이 파란색으로 보이면 활성화된 것입니다.)
#
#   * **코드에서 키 불러오기**
#     이제 아래 코드를 실행해서, 방금 등록한 비밀 열쇠를 우리 프로그램으로 가져와 봅시다.

# %%
# 1. 필요한 도구를 불러옵니다.
import google.generativeai as genai
from google.colab import userdata # Colab의 보안 비밀(Secrets) 기능을 사용하기 위한 도구

# 2. 'GOOGLE_API_KEY'라는 이름으로 저장된 비밀 키를 가져옵니다.
try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    # 3. 가져온 키를 제미나이 설정에 등록합니다.
    genai.configure(api_key=GOOGLE_API_KEY)

    print("✅ API 키가 성공적으로 설정되었습니다! 다음 단계로 진행할 준비가 되었습니다.")

except Exception as e:
    print("🚨 API 키 설정에 실패했습니다. 왼쪽 '🔑' 아이콘에서 API 키의 이름과 값이 정확히 설정되었는지 다시 확인해주세요.")
# Out:
# ✅ API 키가 성공적으로 설정되었습니다! 다음 단계로 진행할 준비가 되었습니다.

# %% [markdown]
# 위 코드 셀을 실행했을 때 "✅ API 키가 성공적으로 설정되었습니다\!"라는 메시지가 나타나면, 모든 환경 설정이 완벽하게 끝난 것입니다.

# %% [markdown]
# ### **2. 오디오 및 이미지 입력 함수 제작**
#
# 이제 이번 실습의 핵심인 '입력' 부분을 만들 차례입니다. 우리는 두 개의 함수를 만들 것입니다.
#
# *   `capture_photo()`: 여러분 컴퓨터의 웹캠을 켜서 사진을 찍고, 그 사진을 Colab 환경에 파일로 저장하는 함수
# *   `record_audio()`: 여러분 컴퓨터의 마이크를 켜서 음성을 녹음하고, 그 음성을 Colab 환경에 파일로 저장하는 함수
#
# 이 과정은 Python 코드(Colab 서버에서 실행)가 여러분의 웹 브라우저(여러분 컴퓨터에서 실행)에 있는 장치(웹캠, 마이크)를 제어해야 하므로, Python과 JavaScript가 함께 작동하는 방식으로 구현됩니다.

# %% [markdown]
# ### **2-1. 실시간 이미지 캡처 함수 (`capture_photo`)**
#
# 먼저 웹캠으로 사진을 찍는 기능을 만들어 보겠습니다.
#
# #### **필요한 도구(라이브러리) 가져오기**
#
# 코드를 작성하기 전에, 우리가 사용할 다양한 기능이 담긴 '도구 상자(라이브러리)'를 불러와야 합니다.

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import PIL
import io
import numpy as np

# %% [markdown]
# #### **이미지 캡처 함수 정의**
#
# 이제 본격적으로 웹캠을 제어하고 사진을 찍는 `capture_photo` 함수를 만듭니다. 함수의 내부 동작을 단계별로 살펴보세요.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import cv2
import numpy as np
from datetime import datetime

def capture_photo(quality=0.8):
  """
  Google Colab 환경에서 웹캠을 사용하여 이미지를 캡처하고 저장합니다. (수정된 버전)
  """
  # 자바스크립트 코드를 하나의 문자열로 통합 (함수 정의 + 실행)
  js_code = f"""
    async function takePhoto(quality) {{
      // 1. UI 요소 생성 (비디오, 버튼 등)
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = '캡처';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({{video: true}});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Colab의 출력 프레임 크기에 맞게 UI 조정
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // 2. 캡처 버튼 클릭 대기
      await new Promise((resolve) => capture.onclick = resolve);

      // 3. 캔버스에 현재 프레임 그리기
      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);

      // 4. 스트림 및 UI 정리
      stream.getTracks().forEach(track => track.stop());
      document.body.removeChild(div);

      // 5. 이미지 데이터를 Base64로 인코딩하여 반환
      return canvas.toDataURL('image/jpeg', quality);
    }}
    // 정의한 함수를 바로 실행하여 결과를 반환
    takePhoto({quality});
  """

  try:
    # 위에서 정의하고 실행한 자바스크립트 코드의 결과를 받음
    data_url = eval_js(js_code)

    # 데이터 URL 디코딩 (헤더 제거, Base64 디코딩)
    binary_data = b64decode(data_url.split(',')[1])

    # OpenCV에서 사용할 수 있는 numpy 배열로 변환
    nparr = np.frombuffer(binary_data, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # 파일로 저장
    filename = f"capture_{datetime.now().strftime('%Y%m%d_%H%M%S')}.jpg"
    cv2.imwrite(filename, img)

    print(f"✅ 이미지가 '{filename}' 파일로 저장되었습니다.")
    return filename
  except Exception as err:
    # eval_js에서 오류가 발생하면 이 부분이 실행됩니다.
    print(f"오류: 웹캠을 사용할 수 없습니다. ({err})")
    print("브라우저에서 카메라 접근 권한을 허용했는지 확인해주세요.")
    return None

# --- 함수 실행 및 결과 확인 ---
image_file = capture_photo()

# 저장된 이미지 확인 (선택 사항)
if image_file:
  from IPython.display import Image
  display(Image(image_file))
# Out:
# ✅ 이미지가 'capture_20250813_172441.jpg' 파일로 저장되었습니다.

# %% [markdown]
# ### **2-2. 실시간 음성 녹음 함수 (`record_audio`)**
#
# 이번에는 마이크로 음성을 녹음하는 기능을 만들겠습니다. 이미지 캡처와 거의 동일한 원리로 작동합니다.
#
# #### **필요한 도구(라이브러리) 가져오기**
#
# 오디오 처리를 위해 `pydub`이라는 라이브러리를 추가로 설치하고 사용합니다. 브라우저가 녹음하는 오디오 형식(WebM)을 AI가 더 잘 이해하는 표준 형식(WAV)으로 변환하는 데 꼭 필요합니다.

# %%
# !pip install pydub -q

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import pydub
import io
from datetime import datetime

def record_audio(filename_prefix="audio_record"):
  """
  Google Colab 환경에서 마이크를 사용하여 오디오를 녹음하고 WAV 파일로 저장합니다. (수정된 버전)
  """
  # 자바스크립트 코드를 하나의 문자열로 통합
  js_code = """
    async function recordAudio() {
      // 1. UI 요소 생성 (버튼)
      const div = document.createElement('div');
      const startButton = document.createElement('button');
      startButton.textContent = '녹음 시작';
      div.appendChild(startButton);

      const stopButton = document.createElement('button');
      stopButton.textContent = '녹음 중지';
      stopButton.disabled = true;
      div.appendChild(stopButton);

      const status = document.createElement('p');
      status.textContent = '버튼을 눌러 녹음을 시작하세요.';
      div.appendChild(status);

      // Colab 출력창에 UI 표시
      document.body.appendChild(div);
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // 2. 녹음 관련 설정
      const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
      const mediaRecorder = new MediaRecorder(stream);
      let audioChunks = [];

      mediaRecorder.ondataavailable = event => {
        audioChunks.push(event.data);
      };

      // 3. 녹음 시작/중지 로직
      const startPromise = new Promise(resolve => {
        startButton.onclick = () => {
          mediaRecorder.start();
          startButton.disabled = true;
          stopButton.disabled = false;
          status.textContent = '녹음 중...';
          resolve();
        };
      });

      const stopPromise = new Promise(resolve => {
        stopButton.onclick = () => {
          mediaRecorder.stop();
          stopButton.disabled = true;
          status.textContent = '녹음 완료. 처리 중...';
          resolve();
        };
      });

      await startPromise;
      await stopPromise;

      // 4. 녹음 데이터 처리 및 반환
      return new Promise(resolve => {
        mediaRecorder.onstop = () => {
          const audioBlob = new Blob(audioChunks, { type: 'audio/webm' });
          const reader = new FileReader();
          reader.readAsDataURL(audioBlob);
          reader.onloadend = () => {
            const base64data = reader.result;
            // 스트림 및 UI 정리
            stream.getTracks().forEach(track => track.stop());
            document.body.removeChild(div);
            resolve(base64data);
          };
        };
      });
    }
    // 정의한 함수를 바로 실행하여 결과를 반환
    recordAudio();
  """

  try:
    # 위에서 정의하고 실행한 자바스크립트 코드의 결과를 받음
    data_url = eval_js(js_code)

    # 데이터 URL 디코딩
    binary_data = b64decode(data_url.split(',')[1])

    # 브라우저는 보통 webm/opus 포맷으로 녹음하므로, pydub을 사용해 wav로 변환
    audio_segment = pydub.AudioSegment.from_file(io.BytesIO(binary_data), format="webm")

    # 파일로 저장
    filename = f"{filename_prefix}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.wav"
    audio_segment.export(filename, format="wav")

    print(f"✅ 오디오가 '{filename}' 파일로 저장되었습니다.")
    return filename
  except Exception as err:
    # eval_js에서 오류가 발생하면 이 부분이 실행됩니다.
    print(f"오류: 마이크를 사용할 수 없습니다. ({err})")
    print("브라우저에서 마이크 접근 권한을 허용했는지 확인해주세요.")
    return None

# --- 함수 실행 및 결과 확인 ---
audio_file = record_audio()

# 저장된 오디오 재생 (선택 사항)
if audio_file:
  from IPython.display import Audio
  display(Audio(audio_file, autoplay=False))
# Out:
# ✅ 오디오가 'audio_record_20250813_172528.wav' 파일로 저장되었습니다.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **3. Gemini 2.5 Pro 모델 호출: 이미지와 오디오를 하나로!**
#
# 이제 가장 흥미로운 부분입니다. 앞에서 캡처한 이미지와 녹음한 음성을 **동시에** Gemini 2.5 Pro 모델에게 전달하여, 모델이 시청각 정보를 통합적으로 이해하고 답변하게 만들어 보겠습니다.
#
# 이 셀 하나만 실행하면, API 키 설정부터 모델 호출까지 모든 과정이 자동으로 진행됩니다.

# %%
# --- 이 셀 하나만 실행하면 됩니다 ---

import google.generativeai as genai
from google.colab import userdata
from IPython.display import Markdown
import os

# --- 0. API 키 설정 (가장 중요!) ---
# 모델 호출 직전에 항상 API 키를 설정하여 런타임 초기화 문제에 대비합니다.
try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=GOOGLE_API_KEY)
    print("✅ API 키 설정이 완료되었습니다.")
except Exception as e:
    print(f"❌ API 키 설정 오류: {e}. Colab Secrets에 'GOOGLE_API_KEY'가 올바르게 설정되었는지 확인해주세요.")
    # API 키가 없으면 더 이상 진행하지 않도록 여기서 중단합니다.
    raise SystemExit("API 키 설정이 필요합니다.")

# --- 사전 준비: 파일 존재 여부 확인 ---
# image_file, audio_file 변수가 정의되어 있는지 확인합니다.
if 'image_file' not in globals() or not os.path.exists(image_file):
    print("❌ 오류: 이미지 파일이 없습니다. 먼저 웹캠 캡처 코드를 실행해주세요.")
elif 'audio_file' not in globals() or not os.path.exists(audio_file):
    print("❌ 오류: 오디오 파일이 없습니다. 먼저 마이크 녹음 코드를 실행해주세요.")
else:
    print(f"✅ 준비 완료: 이미지({image_file})와 오디오({audio_file})를 사용합니다.")
    print("-" * 20)

    try:
        # --- 1. 파일 업로드 ---
        print("⏳ 파일을 Gemini 서버에 업로드하는 중...")
        uploaded_image = genai.upload_file(path=image_file)
        uploaded_audio = genai.upload_file(path=audio_file)
        print("✅ 파일 업로드 완료!")
        print("-" * 20)

        # --- 2. 모델 선택 ---
        model = genai.GenerativeModel(model_name='gemini-2.5-pro')

        # --- 3. 프롬프트 구성 ---
        prompt_parts = [
            "이 이미지와 오디오를 함께 분석해줘.",
            "이미지에는 특정 사물이 있고, 오디오에는 그 사물에 대한 질문이 녹음되어 있어.",
            "이미지와 오디오 내용을 종합적으로 파악해서, 오디오에 담긴 질문에 대한 답변을 생성해줘.",
            "---",
            "이미지:", uploaded_image,
            "오디오:", uploaded_audio
        ]

        # --- 4. 모델 호출 및 결과 출력 ---
        print("🧠 Gemini가 분석하고 답변을 생성하는 중...")
        response = model.generate_content(prompt_parts)
        print("\n🎉 Gemini의 답변:")
        display(Markdown(response.text))

    except Exception as e:
        print(f"❌ 모델 호출 중 오류가 발생했습니다: {e}")
# Out:
# ✅ API 키 설정이 완료되었습니다.
# ✅ 준비 완료: 이미지(capture_20250813_172441.jpg)와 오디오(audio_record_20250813_172528.wav)를 사용합니다.
# --------------------
# ⏳ 파일을 Gemini 서버에 업로드하는 중...
# ✅ 파일 업로드 완료!
# --------------------
# 🧠 Gemini가 분석하고 답변을 생성하는 중...
#
# 🎉 Gemini의 답변:
# 네, 사진을 보니 안경을 쓰고 있습니다.

# %%
# 이 코드를 별도의 셀에 추가하여 실행해보세요.

# LV 1-1. 대화 루프 만들기
# 이전에 정의한 capture_photo, record_audio 함수와
# API 키 설정이 완료되었다고 가정합니다.

# 모델을 미리 준비합니다.
model = genai.GenerativeModel(model_name='gemini-2.5-pro')

while True:
    print("\n--- 새로운 대화를 시작합니다 ---")

    # 1. 사용자에게 계속할지 묻기
    user_input = input("대화를 시작하려면 Enter를, 종료하려면 'exit'를 입력하세요: ")
    if user_input.lower() == 'exit':
        print("프로그램을 종료합니다.")
        break

    # 2. 사진과 오디오 캡처
    image_file = capture_photo()
    if not image_file: # 사진 캡처에 실패하면 다시 시작
        continue

    audio_file = record_audio()
    if not audio_file: # 오디오 녹음에 실패하면 다시 시작
        continue

    # 3. 파일 업로드 및 모델 호출 (기존 코드와 거의 동일)
    try:
        print("⏳ 파일 업로드 및 분석 중...")
        uploaded_image = genai.upload_file(path=image_file)
        uploaded_audio = genai.upload_file(path=audio_file)

        prompt_parts = [
            "당신은 친절한 사물 박사입니다. 사용자가 보여주는 이미지와 음성 질문을 듣고, 아이에게 설명하듯 쉽고 재미있게 답변해주세요.",
            "이미지:", uploaded_image,
            "오디오:", uploaded_audio
        ]

        response = model.generate_content(prompt_parts, stream=True)

        print("\n🤖 젬돌이의 답변:")
        full_response = ""
        for chunk in response:
            print(chunk.text, end="")
            full_response += chunk.text
        print("\n" + "-"*20)

        # (LV 1-2. 음성 답변 기능을 위해 추가)
        # tts_answer(full_response)

    except Exception as e:
        print(f"❌ 오류가 발생했습니다: {e}")

    # 사용된 파일 정리 (선택 사항)
    os.remove(image_file)
    os.remove(audio_file)
# Out:
# --- 새로운 대화를 시작합니다 ---
# 대화를 시작하려면 Enter를, 종료하려면 'exit'를 입력하세요:
# ✅ 이미지가 'capture_20250813_172605.jpg' 파일로 저장되었습니다.
# ✅ 오디오가 'audio_record_20250813_172608.wav' 파일로 저장되었습니다.
# ⏳ 파일 업로드 및 분석 중...
#
# 🤖 젬돌이의 답변:
# 와, 우리 친구! 보라색 칫솔을 입에 쏘옥 넣고 "나는 양치를 하고 있네" 하고 씩씩하게 말해주었구나!
#
# 맞아! 그건 바로 우리 치아를 깨끗하고 튼튼하게 지켜주는 **'칫솔'**이라는 아주 멋진 친구야!
#
# 사물 박사님이 칫솔 친구에 대해 재미있게 설명해 줄게!
#
# 우리가 맛있는 음식을 냠냠 먹고 나면, 입속에 '충치 벌레'라는 나쁜 악당들이 생길 수 있거든. 이 악당들은 우리 이를 아프게 하고 까맣게 만들려고 해.
#
# 이때 칫솔 친구가 나타나서 '치카치카' 소리를 내며 나쁜 벌레들을 싹~ 물리쳐주는 거지! 🦸‍♂️
#
# 칫솔 머리에 있는 부드러운 털들이 비눗방울 같은 치약 거품이랑 힘을 합쳐서, 치아 사이에 숨어있는 음식 찌꺼기랑 나쁜 벌레들을 깨끗하게 청소해주는 거야. 마치 작은 빗자루로 방을 쓰는 것처럼 말이야!🧹
#
# 그래서 양치를 하고 나면 입안이 시원~해지고, 우리 친구의 미소는 보석처럼 반짝반짝 빛나게 된단다! ✨
#
# 이렇게 매일 칫솔이랑 친하게 지내면 충치 벌레 걱정 없이 항상 건강하고 예쁜 이를 가질 수 있을 거야. 정말 대단한걸! 궁금한 게 있으면 이 사물 박사님에게 언제든지 또 물어봐 줘
# --------------------
#
# --- 새로운 대화를 시작합니다 ---
# 대화를 시작하려면 Enter를, 종료하려면 'exit'를 입력하세요:
# ✅ 이미지가 'capture_20250813_172710.jpg' 파일로 저장되었습니다.
# ✅ 오디오가 'audio_record_20250813_172846.wav' 파일로 저장되었습니다.
# ...

# %% [markdown]
# ### **LV 2. Gemini와 실시간으로 대화하기: 진정한 음성 AI 어시스턴트**
#
# 이전 단계에서는 이미지와 녹음된 오디오 '파일'을 업로드하여 Gemini에게 질문했습니다. 이는 정적인 정보를 분석하는 강력한 방법입니다. 하지만 AI와 정말 '대화'를 나눈다고 느끼려면 어떻게 해야 할까요? 마치 사람과 대화하듯, 내가 말을 하면 AI가 바로 듣고 음성으로 대답해주는 경험 말입니다.
#
# 이번 실습에서는 한 단계 더 나아가, Gemini의 **'네이티브 오디오(Native Audio)'** 기능과 **'Live Connect API'**를 사용하여 파일 저장 없이 실시간으로 음성을 주고받는 대화형 AI를 만들어 봅니다.

# %% [markdown]
# ### **무엇이 달라졌을까요?**
#
# *   **🚀 파일 없는 실시간 스트리밍:** 더 이상 웹캠 사진이나 오디오 파일을 PC에 저장하고 업로드하는 과정이 없습니다. 마이크로 입력된 음성 데이터가 메모리에서 바로 Gemini 서버로 실시간 전송(스트리밍)됩니다.
# *   **🗣️ 음성으로 답하는 AI:** Gemini가 텍스트가 아닌, 자연스러운 목소리로 직접 대답합니다. `VOICE_NAME` 설정을 통해 다양한 목소리 톤도 선택할 수 있습니다.
# *   **⚡️ 낮은 지연 시간(Low Latency):** 이 방식은 빠른 응답 속도를 위해 특별히 설계되어, 실제 대화처럼 끊김이 적은 상호작용을 경험할 수 있습니다.
#
# #### **코드 실행 가이드**
#
# 아래 코드들은 세 개의 셀로 구성되어 있으며, 순서대로 실행해야 합니다.
#
# *   **[셀 0: 기본 준비]**
#     대화에 필요한 라이브러리(`google-genai`, `pydub`)와 실시간 오디오 처리에 필수적인 도구(`ffmpeg`)를 설치하고, API 키를 설정합니다.
#
# *   **[셀 1: 실시간 마이크 입력기]**
#     브라우저에서 바로 마이크를 사용할 수 있는 UI('녹음 시작' 버튼)를 띄웁니다. 이 부분은 여러분의 목소리를 Gemini가 즉시 이해할 수 있는 순수한 오디오 데이터(PCM 16kHz 형식)로 변환하는 준비를 합니다.
#
# *   **[셀 2: Gemini와 실시간 대화 시작]**
#     가장 핵심적인 부분입니다. 이 셀을 실행하면 **[셀 1]**에서 만든 녹음 UI가 나타납니다. '🎙️ 녹음 시작' 버튼을 누르고 말하면, 여러분의 목소리가 Gemini에게 전달되고, 잠시 후 AI의 음성 답변이 스피커로 자동 재생됩니다.
#
# 이제 아래 코드를 실행하여, 여러분만의 음성 AI 어시스턴트와 대화하는 미래를 경험해보세요

# %%
# --- 셀 0: 라이브러리 설치 & ffmpeg 준비 ---
# !pip -q install -U google-genai pydub
# !apt -yqq install ffmpeg

import os, io, wave, asyncio, base64
from datetime import datetime

# Colab 비밀키(🔑)에서 GOOGLE_API_KEY 읽어오기
try:
    from google.colab import userdata
    api_key = userdata.get('GOOGLE_API_KEY')
except Exception:
    api_key = os.environ.get("GOOGLE_API_KEY", "")

if not api_key:
    print("⚠️ GOOGLE_API_KEY 가 설정되어 있지 않습니다. Colab '🔑 보안 비밀'에 추가하거나 환경변수로 넣어주세요.")
else:
    os.environ["GOOGLE_API_KEY"] = api_key
    print("✅ GOOGLE_API_KEY 로드 완료")

print("✅ 설치/셋업 완료 (google-genai, pydub, ffmpeg)")
# Out:
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ✅ GOOGLE_API_KEY 로드 완료
# ✅ 설치/셋업 완료 (google-genai, pydub, ffmpeg)

# %% [markdown]
# ### **셀 1: 사용자의 목소리를 AI가 알아듣는 언어로 번역하기**
#
# 이 셀은 실제 대화의 '귀' 역할을 하는 매우 중요한 부분입니다. 우리가 마이크에 대고 말하는 음성을 Gemini가 즉시 이해하고 처리할 수 있는 깨끗한 '디지털 오디오 신호'로 변환하는 모든 준비 과정을 담당합니다.
#
# 이 코드는 크게 두 가지 일을 합니다.
#
# 1.  **🎙️ 브라우저에 '녹음기' UI 띄우기 (JavaScript)**
#     *   코드의 앞부분(`js_record = r"""..."""`)은 여러분의 웹 브라우저에서 직접 실행되는 JavaScript 코드입니다.
#     *   이 코드가 실행되면 Colab 출력 창에 **`🎙️ 녹음 시작`**과 **`⏹️ 녹음 중지`** 버튼이 나타납니다.
#     *   **(중요!)** 이 기능을 처음 사용하면 브라우저 상단에 "이 사이트에서 마이크를 사용하도록 허용하시겠습니까?"라는 권한 요청 팝업이 나타납니다. **반드시 '허용'을 클릭해야 합니다.**
#     *   사용자가 녹음한 음성은 웹 표준 오디오 형식(WebM)으로 캡처되어 파이썬 코드로 전달됩니다.
#
# 2.  **⚙️ 오디오 데이터를 'AI 맞춤형'으로 변환하기 (Python)**
#     *   `record_microphone_to_pcm16k` 함수는 브라우저로부터 전달받은 WebM 오디오를 AI 모델이 가장 선호하는 형식으로 변환하는 '전문 번역가'입니다.
#     *   Gemini의 실시간 음성 모델은 **16kHz 샘플링 속도, 모노 채널, 16비트 깊이의 PCM 데이터**를 요구합니다. 이 함수는 `pydub`과 `ffmpeg` 도구를 사용하여 오디오를 이 특정 규격에 정확히 맞춰줍니다.
#     *   이렇게 변환된 순수한 오디오 데이터는 파일로 저장되지 않고, 다음 셀에서 바로 Gemini 서버로 전송될 준비를 마칩니다.
#
# 이 셀을 실행하면 "🎛️ 준비 완료"라는 메시지가 나타나며, 다음 단계에서 실시간 대화를 시작할 모든 기술적인 준비가 완료되었음을 의미합니다.

# %%
# --- 셀 1: 마이크 녹음 UI(JS) + webm→PCM16k 변환 ---
from IPython.display import Javascript, display
from google.colab.output import eval_js
from pydub import AudioSegment

js_record = r"""
async function recordAudioUI() {
  const div = document.createElement('div');
  div.style.margin = '8px 0';
  const startBtn = document.createElement('button');
  const stopBtn  = document.createElement('button');
  const status   = document.createElement('p');
  startBtn.textContent = '🎙️ 녹음 시작';
  stopBtn.textContent  = '⏹️ 녹음 중지';
  stopBtn.disabled = true;
  status.textContent = '버튼을 눌러 녹음을 시작하세요.';
  status.style.margin = '8px 0 0 0';
  div.appendChild(startBtn); div.appendChild(stopBtn); div.appendChild(status);
  document.body.appendChild(div);
  google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

  const stream = await navigator.mediaDevices.getUserMedia({audio:true});
  const rec = new MediaRecorder(stream, {mimeType: 'audio/webm'});
  const chunks = [];
  rec.ondataavailable = e => { if (e.data.size > 0) chunks.push(e.data); };

  await new Promise(resolve => {
    startBtn.onclick = () => {
      rec.start();
      startBtn.disabled = true; stopBtn.disabled = false;
      status.textContent = '녹음 중... 말하세요.';
    };
    stopBtn.onclick = () => {
      rec.stop(); stopBtn.disabled = true;
      status.textContent = '처리 중...';
      resolve();
    };
  });

  const base64 = await new Promise(resolve => {
    rec.onstop = async () => {
      stream.getTracks().forEach(t => t.stop());
      const blob = new Blob(chunks, {type: 'audio/webm'});
      const reader = new FileReader();
      reader.onloadend = () => {
        document.body.removeChild(div);
        resolve(reader.result); // ...};
      reader.readAsDataURL(blob);
    };
  });

  return base64;
}
recordAudioUI();
"""

def record_microphone_to_pcm16k():
  """브라우저에서 녹음(webm/opus) → 16kHz 모노 16-bit PCM 바이트로 변환"""
  data_url = eval_js(js_record)               # ← 문자열 그대로 넘겨야 함 (Javascript(...) 객체 X)
  if not isinstance(data_url, str) or not data_url.startswith("data:"):
      raise RuntimeError("브라우저 녹음 결과가 비정상입니다. 마이크 권한/브라우저 콘솔을 확인하세요.")
  b64 = data_url.split(",")[1]
  webm_bytes = base64.b64decode(b64)          # ← b64decode (b6decode 오타 금지!)
  seg = AudioSegment.from_file(io.BytesIO(webm_bytes), format="webm")  # ffmpeg 필요
  seg = seg.set_frame_rate(16000).set_channels(1).set_sample_width(2)  # 16kHz, mono, 16-bit
  return seg.raw_data  # WAV 헤더 없이 순수 PCM 바이트

print("🎛️ 준비 완료: 다음 셀에서 녹음→모델 응답까지 실행합니다.")
# Out:
# 🎛️ 준비 완료: 다음 셀에서 녹음→모델 응답까지 실행합니다.

# %% [markdown]
# ### **셀 2: 대화의 시작, Gemini와 실시간 음성으로 소통하기**
#
# 드디어 모든 준비가 끝났습니다! 이 셀은 앞에서 만든 '마이크 입력기'와 'API 설정'을 모두 사용하여, Gemini와 실시간으로 한 턴의 음성 대화를 나누는 전체 과정을 지휘하는 **'메인 컨트롤러'**입니다.
#
# 이 셀을 실행하면, 다음과 같은 마법 같은 일들이 순서대로 일어납니다.
#
# 1.  **[셀 1]**에서 만들었던 **`🎙️ 녹음 시작`** 버튼이 나타납니다.
# 2.  버튼을 누르고 여러분의 질문이나 말을 녹음합니다.
# 3.  녹음된 목소리는 실시간으로 Gemini 서버에 안전하게 전송됩니다.
# 4.  Gemini는 여러분의 말을 분석하고, 설정된 목소리로 답변을 생성합니다.
# 5.  생성된 AI의 음성 답변이 여러분의 컴퓨터 스피커를 통해 **자동으로 재생됩니다.**
#
# #### **⚙️ 대화 설정 커스터마이징하기**
#
# 코드를 실행하기 전에, 상단의 몇 가지 설정을 바꾸어 AI의 성격과 목소리를 바꿀 수 있습니다.
#
# *   `MODEL_NAME`: 대화에 사용할 AI 모델을 지정합니다. 현재는 실시간 음성 대화에 최적화된 `gemini-1.5-flash-preview-native-audio-dialog`가 설정되어 있습니다.
# *   `VOICE_NAME`: AI의 목소리를 선택합니다. `"Kore"`는 자연스러운 한국어 여성 목소리입니다. 다른 목소리도 테스트해볼 수 있습니다.
# *   `SYSTEM_INSTRUCTION`: AI의 역할과 말투를 정해주는 **가장 중요한 지시문**입니다. 예를 들어 `"너는 우주에 대해 모든 것을 아는 박사님이야. 어린 아이에게 설명하듯 쉽고 재미있게 말해줘."` 와 같이 구체적으로 역할을 부여하면, AI가 그 역할에 맞춰 대답합니다.
#
# 이제 아래 셀을 실행하여 여러분의 첫 실시간 AI 음성 대화를 시작해보세요

# %%
# --- 셀 2: Live API (네이티브 오디오) 한 턴 대화 — Colab용 완성본 ---
import os, asyncio, wave
from datetime import datetime
import numpy as np
from IPython.display import Audio, display

from google import genai
from google.genai import types

MODEL_NAME = "gemini-2.5-flash-preview-native-audio-dialog"
VOICE_NAME = "Kore"
USE_V1ALPHA_FEATURES   = False
ENABLE_AFFECTIVE_DIALOG = False
ENABLE_PROACTIVE_AUDIO  = False
SYSTEM_INSTRUCTION = "한국어로 친근하고 명료하게 답하라."

client_kwargs = {}
if USE_V1ALPHA_FEATURES:
    client_kwargs["http_options"] = {"api_version": "v1alpha"}

def _init_genai_client():
    api_key = os.environ.get("GOOGLE_API_KEY","").strip()
    if not api_key:
        try:
            from google.colab import userdata
            api_key = (userdata.get("GOOGLE_API_KEY") or "").strip()
            if api_key:
                os.environ["GOOGLE_API_KEY"] = api_key
        except Exception:
            pass
    if api_key:
        print("🔑 Using Google AI API (api_key)")
        return genai.Client(api_key=api_key, **client_kwargs)

    project = os.environ.get("GOOGLE_CLOUD_PROJECT","").strip()
    region  = os.environ.get("GOOGLE_CLOUD_REGION","").strip()
    if project and region:
        print(f"🏢 Using Vertex AI (project={project}, region={region})")
        return genai.Client(vertexai=True, project=project, location=region, **client_kwargs)

    raise ValueError("Missing credentials...")

client = _init_genai_client()

def build_live_config():
    base = dict(
        response_modalities=["AUDIO"],
        system_instruction=SYSTEM_INSTRUCTION,
        speech_config=types.SpeechConfig(
            voice_config=types.VoiceConfig(
                prebuilt_voice_config=types.PrebuiltVoiceConfig(voice_name=VOICE_NAME)
            )
        ),
    )
    if USE_V1ALPHA_FEATURES:
        base["enable_affective_dialog"] = bool(ENABLE_AFFECTIVE_DIALOG)
        base["proactivity"] = {"proactive_audio": bool(ENABLE_PROACTIVE_AUDIO)}
    return types.LiveConnectConfig(**base)
import io, wave
import numpy as np

def ensure_raw_pcm_and_rate(buf: bytes):
    """
    입력 바이트가 WAV이면 헤더 제거 + (필요 시) 모노 다운믹스하여 RAW PCM(int16, little-endian)으로 변환.
    RAW PCM이면 그대로 반환. 함께 샘플레이트도 돌려줍니다.
    """
    # WAV 시그니처 확인
    if len(buf) >= 12 and buf[:4] == b"RIFF" and buf[8:12] == b"WAVE":
        with wave.open(io.BytesIO(buf), "rb") as w:
            nchan  = w.getnchannels()
            sampw  = w.getsampwidth()
            rate   = w.getframerate()
            nframe = w.getnframes()
            assert sampw == 2, f"16-bit PCM이 아님 (sampwidth={sampw})"

            frames = w.readframes(nframe)  # interleaved int16 LE
            if nchan == 1:
                pcm = frames  # 이미 모노
            else:
                # 스테레오 이상 → 첫 채널만 사용 (평균하면 음량이 줄 수 있음)
                arr = np.frombuffer(frames, dtype="<i2").reshape(-1, nchan)
                mono = arr[:, 0].astype("<i2")
                pcm = mono.tobytes()
            return pcm, rate

    # RAW PCM으로 간주 (셀1의 녹음 함수가 16k/mono/int16을 만든다고 가정)
    # 필요하면 여기서 샘플레이트를 바꿔주세요.
    return buf, 16000
async def one_turn_native_audio():
    raw = record_microphone_to_pcm16k()  # 셀1에서 만든 함수 (WAV일 수도 있음)
    pcm_bytes, sr = ensure_raw_pcm_and_rate(raw)

    config = build_live_config()
    out_wav = f"reply_{datetime.now().strftime('%H%M%S')}.wav"

    async with client.aio.live.connect(model=MODEL_NAME, config=config) as session:
        # ⬇ 오디오 → 실시간 입력 경로로 전송
        await session.send_realtime_input(
            audio=types.Blob(data=pcm_bytes, mime_type=f"audio/pcm;rate={sr}")
        )
        await session.send_realtime_input(audio_stream_end=True)

        # 24kHz 출력 수신/저장
        with wave.open(out_wav, "wb") as wf:
            wf.setnchannels(1); wf.setsampwidth(2); wf.setframerate(24000)
            async for msg in session.receive():
                if getattr(msg, "data", None):
                    wf.writeframes(msg.data)
                sc = getattr(msg, "server_content", None)
                if sc and (getattr(sc, "turn_complete", False) or getattr(sc, "generation_complete", False)):
                    break
                if getattr(msg, "go_away", None):
                    break
    return out_wav


reply = await one_turn_native_audio()
display(Audio(filename=reply, autoplay=True))
print(f"🎧 모델 응답 파일: {reply}")
# Out:
# 🔑 Using Google AI API (api_key)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 🎧 모델 응답 파일: reply_180005.wav
